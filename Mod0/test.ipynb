# %%
import pandas as pd

# %%
data1 = pd.read_csv("fellows_1.csv",)
data2 = pd.read_csv("fellows_2.csv",)

# %%
data1.head()
# Out:
#         Name  Age (Years) Gender/Sex  Height (Inch)  Commute Time (Mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   Favorite Color Favorite Fruit Android or iphone Birthday (MM/DD)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              Race  # of Siblings   Favorite Pizza Fav Genre  Languages Spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
data1.columns
# Out:
# Index(['Name', 'Age (Years)', 'Gender/Sex', 'Height (Inch)',
#        'Commute Time (Mins)', 'Favorite Color', 'Favorite Fruit',
#        'Android or iphone', 'Birthday (MM/DD)', 'Race', '# of Siblings',
#        'Favorite Pizza', 'Fav Genre', 'Languages Spoken', 'Borough',
#        'Dream Job', 'Dream Company'],
#       dtype='object')

# %%
data2.head()
# Out:
#       Name  Age     Sex           Height Commute Time  Transportation  \
# 0    Itzel   21  Female              5'2      70 mins  R , A ,L Train
# 1    Angel   19    Male  5'11 with timbs  100 minutes  Bx27/6&N train
# 2    Kabbo   24    Male              5'9  150 minutes       Q42, J, N
# 3  Vincent   24    Male              5'7           60       A/D Train
#
#   Fav Color     Fav Fruit Andriod Or Iphone   Country Of Origin         Race  \
# 0    purple  pomegranates           Andriod               U.S.A       Latino
# 1    Purple    Watermelon            Iphone  Dominican Republic  Afro-Latino
# 2     Black        Apples            iPhone          Bangladesh  South Asian
# 3     Beige        banana            iphone   Domincan Republic  Afro-Latino
#
#    Birthday  # of Siblings   Favorite Pizza Fav Genre  \
# 0   9/18/03              3  Buffalo chicken     metal
# 1  10/19/05              2    Chicken Ranch       Pop
# 2   7/16/00              1              Pep   Hip-Hop
# ...

# %%
data1_columns = data1.columns.tolist()
data2_columns = data2.columns.tolist()

# %%
data1_column_lower_case = [_.lower() for _ in data1_columns]
data2_column_lower_case = [_.lower() for _ in data2_columns]

# %%
data1.columns = data1_column_lower_case
data2.columns = data2_column_lower_case

# %%
data1.head()
# Out:
#         name  age (years) gender/sex  height (inch)  commute time (mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   favorite color favorite fruit android or iphone birthday (mm/dd)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              race  # of siblings   favorite pizza fav genre  languages spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
data2.head()
# Out:
#       name  age     sex           height commute time  transportation  \
# 0    Itzel   21  Female              5'2      70 mins  R , A ,L Train
# 1    Angel   19    Male  5'11 with timbs  100 minutes  Bx27/6&N train
# 2    Kabbo   24    Male              5'9  150 minutes       Q42, J, N
# 3  Vincent   24    Male              5'7           60       A/D Train
#
#   fav color     fav fruit andriod or iphone   country of origin         race  \
# 0    purple  pomegranates           Andriod               U.S.A       Latino
# 1    Purple    Watermelon            Iphone  Dominican Republic  Afro-Latino
# 2     Black        Apples            iPhone          Bangladesh  South Asian
# 3     Beige        banana            iphone   Domincan Republic  Afro-Latino
#
#    birthday  # of siblings   favorite pizza fav genre  \
# 0   9/18/03              3  Buffalo chicken     metal
# 1  10/19/05              2    Chicken Ranch       Pop
# 2   7/16/00              1              Pep   Hip-Hop
# ...

# %%
tranportation = ["N/A","","",""]
country = ["N/A","","",""]

# %%
data1['tranportation'] = tranportation
data1['country of origin'] = country

# %%
data1.head()
# Out:
#         name  age (years) gender/sex  height (inch)  commute time (mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   favorite color favorite fruit android or iphone birthday (mm/dd)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              race  # of siblings   favorite pizza fav genre  languages spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
data1['tranportation'][0] = '2 and N trains'
# Out:
# /var/folders/h0/75t8pd8571n2l1zzjcyqp7kh0000gp/T/ipykernel_29116/3329041811.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['tranportation'][0] = '2 and N trains'
# ...

# %%
data1['country of origin'][0] = 'Guinea'
# Out:
# /var/folders/h0/75t8pd8571n2l1zzjcyqp7kh0000gp/T/ipykernel_29116/3247971416.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data1['country of origin'][0] = 'Guinea'
# ...

# %%
data1.head( )
# Out:
#         name  age (years) gender/sex  height (inch)  commute time (mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   favorite color favorite fruit android or iphone birthday (mm/dd)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              race  # of siblings   favorite pizza fav genre  languages spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
data2.rename(columns={"age": "age (years)", "sex": "gender/sex", "height": "height (inch)", "commute time": "commute time (mins)", "fav color":"favorite color", "fav fruit":"favorite fruit", "birthday":"birthday (mm/dd)"},inplace=True)

# %%
data2.head()
# Out:
#       name  age (years) gender/sex    height (inch) commute time (mins)  \
# 0    Itzel           21     Female              5'2             70 mins
# 1    Angel           19       Male  5'11 with timbs         100 minutes
# 2    Kabbo           24       Male              5'9         150 minutes
# 3  Vincent           24       Male              5'7                  60
#
#    transportation favorite color favorite fruit andriod or iphone  \
# 0  R , A ,L Train         purple   pomegranates           Andriod
# 1  Bx27/6&N train         Purple     Watermelon            Iphone
# 2       Q42, J, N          Black         Apples            iPhone
# 3       A/D Train          Beige         banana            iphone
#
#     country of origin         race birthday (mm/dd)  # of siblings  \
# 0               U.S.A       Latino          9/18/03              3
# 1  Dominican Republic  Afro-Latino         10/19/05              2
# 2          Bangladesh  South Asian          7/16/00              1
# ...

# %%
data1.rename(columns={"tranportation":"transportation"},inplace=True)

# %%
list_of_cols = ["name","age (years)","gender/sex","height (inch)","commute time (mins)","transportation","favorite color","favorite fruit","android or iphone","country of origin","race","birthday (mm/dd)","# of siblings","favorite pizza","fav genre","languages spoken","borough","dream job","dream company"]
data_reordered = data1[list_of_cols]

# %%
data_reordered
# Out:
#         name  age (years) gender/sex  height (inch)  commute time (mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#    transportation favorite color favorite fruit android or iphone  \
# 0  2 and N trains          Black         Mango            Android
# 1                          Green          Mango            Iphone
# 2                           Blue          Mango           Android
# 3                           Blue          Mango            IPHONE
#
#   country of origin            race birthday (mm/dd)  # of siblings  \
# 0            Guinea        Africain            08/07              4
# 1                    White/Hispanic            12/25              2
# ...

# %%
data2
# Out:
#       name  age (years) gender/sex    height (inch) commute time (mins)  \
# 0    Itzel           21     Female              5'2             70 mins
# 1    Angel           19       Male  5'11 with timbs         100 minutes
# 2    Kabbo           24       Male              5'9         150 minutes
# 3  Vincent           24       Male              5'7                  60
#
#    transportation favorite color favorite fruit andriod or iphone  \
# 0  R , A ,L Train         purple   pomegranates           Andriod
# 1  Bx27/6&N train         Purple     Watermelon            Iphone
# 2       Q42, J, N          Black         Apples            iPhone
# 3       A/D Train          Beige         banana            iphone
#
#     country of origin         race birthday (mm/dd)  # of siblings  \
# 0               U.S.A       Latino          9/18/03              3
# 1  Dominican Republic  Afro-Latino         10/19/05              2
# 2          Bangladesh  South Asian          7/16/00              1
# ...

# %%
data2.rename(columns={"andriod or iphone":"android or iphone"},inplace=True)
#merged_df = pd.merge(data_reordered,data2, on=list_of_cols, how="outer")

# %%
data_reordered["height (inch)"] = data_reordered["height (inch)"].astype(str)
data_reordered["commute time (mins)"] = data_reordered["commute time (mins)"].astype(str)
data_reordered["languages spoken"] = data_reordered["languages spoken"].astype(str)

# %%
merged_df = pd.merge(data_reordered,data2, on=list_of_cols, how="outer")

# %%
merged_df
# Out:
#         name  age (years) gender/sex    height (inch) commute time (mins)  \
# 0      Angel           19       Male  5'11 with timbs         100 minutes
# 1  Ibrahima            22       Male               68                 120
# 2      Itzel           21     Female              5'2             70 mins
# 3      Kabbo           24       Male              5'9         150 minutes
# 4      Kevin           22       Male               68                  80
# 5    Rolando           22       Male               69                  60
# 6     Thomas           22       Male               69                  80
# 7    Vincent           24       Male              5'7                  60
#
#    transportation favorite color favorite fruit android or iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
cleaned_height = [ element.split()[0] for element in merged_df["height (inch)"]]

# %%
merged_df["height (inch)"] = cleaned_height

# %%
merged_df
# Out:
#         name  age (years) gender/sex height (inch) commute time (mins)  \
# 0      Angel           19       Male          5'11         100 minutes
# 1  Ibrahima            22       Male            68                 120
# 2      Itzel           21     Female           5'2             70 mins
# 3      Kabbo           24       Male           5'9         150 minutes
# 4      Kevin           22       Male            68                  80
# 5    Rolando           22       Male            69                  60
# 6     Thomas           22       Male            69                  80
# 7    Vincent           24       Male           5'7                  60
#
#    transportation favorite color favorite fruit android or iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
commute_time_list = [element.split()[0] for element in merged_df['commute time (mins)']] 
merged_df["commute time (mins)"] = commute_time_list

# %%
merged_df["commute time (mins)"] = merged_df["commute time (mins)"].astype(int)
#merged_df["height (inch)"] = merged_df["height (inch)"].astype(int)
#merged_df["commute time (mins)"] = merged_df["commute time (mins)"].astype(int)

# %%
merged_df["height (inch)"] = [_.split()[0] for _ in merged_df["height (inch)"]]

# %%
merged_df
# Out:
#         name  age (years) gender/sex height (inch)  commute time (mins)  \
# 0      Angel           19       Male          5'11                  100
# 1  Ibrahima            22       Male            68                  120
# 2      Itzel           21     Female           5'2                   70
# 3      Kabbo           24       Male           5'9                  150
# 4      Kevin           22       Male            68                   80
# 5    Rolando           22       Male            69                   60
# 6     Thomas           22       Male            69                   80
# 7    Vincent           24       Male           5'7                   60
#
#    transportation favorite color favorite fruit android or iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
#merged_df["height (inch)"]
merged_df["fav genre"][1] = "Rap"
# Out:
# /var/folders/h0/75t8pd8571n2l1zzjcyqp7kh0000gp/T/ipykernel_44599/4176808851.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_df["fav genre"][1] = "Rap"
# ...

# %%
merged_df
# Out:
#         name  age (years) gender/sex height (inch)  commute time (mins)  \
# 0      Angel           19       Male          5'11                  100
# 1  Ibrahima            22       Male            68                  120
# 2      Itzel           21     Female           5'2                   70
# 3      Kabbo           24       Male           5'9                  150
# 4      Kevin           22       Male            68                   80
# 5    Rolando           22       Male            69                   60
# 6     Thomas           22       Male            69                   80
# 7    Vincent           24       Male           5'7                   60
#
#    transportation favorite color favorite fruit android or iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
merged_df.columns = [_.title() for _ in merged_df.columns]

# %%
merged_df
# Out:
#         Name  Age (Years) Gender/Sex Height (Inch)  Commute Time (Mins)  \
# 0      Angel           19       Male          5'11                  100
# 1  Ibrahima            22       Male            68                  120
# 2      Itzel           21     Female           5'2                   70
# 3      Kabbo           24       Male           5'9                  150
# 4      Kevin           22       Male            68                   80
# 5    Rolando           22       Male            69                   60
# 6     Thomas           22       Male            69                   80
# 7    Vincent           24       Male           5'7                   60
#
#    Transportation Favorite Color Favorite Fruit Android Or Iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
merged_df["Country Of Origin"] = merged_df["Country Of Origin"].replace("U.S.A", "United States")

# %%
merged_df
# Out:
#         Name  Age (Years) Gender/Sex Height (Inch)  Commute Time (Mins)  \
# 0      Angel           19       Male          5'11                  100
# 1  Ibrahima            22       Male            68                  120
# 2      Itzel           21     Female           5'2                   70
# 3      Kabbo           24       Male           5'9                  150
# 4      Kevin           22       Male            68                   80
# 5    Rolando           22       Male            69                   60
# 6     Thomas           22       Male            69                   80
# 7    Vincent           24       Male           5'7                   60
#
#    Transportation Favorite Color Favorite Fruit Android Or Iphone  \
# 0  Bx27/6&N train         Purple     Watermelon            Iphone
# 1  2 and N trains          Black         Mango            Android
# 2  R , A ,L Train         purple   pomegranates           Andriod
# ...

# %%
data = pd.DataFrame(merged_df)

# %%
data.to_csv("fellows_1_2_merged_dataset.csv")
