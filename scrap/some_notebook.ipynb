# %%
import pandas as pd

ourData = pd.read_csv('Data Challenge 5_12_25 - Sheet1.csv')
print(ourData)
# Out:
#         Name  Age (Years) Gender/Sex  Height (Inch)  Commute Time (Mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   Favorite Color Favorite Fruit Android or iphone Birthday (MM/DD)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              Race  # of Siblings   Favorite Pizza Fav Genre  Languages Spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
print(ourData.head)
# Out:
# <bound method NDFrame.head of         Name  Age (Years) Gender/Sex  Height (Inch)  Commute Time (Mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   Favorite Color Favorite Fruit Android or iphone Birthday (MM/DD)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              Race  # of Siblings   Favorite Pizza Fav Genre  Languages Spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# ...

# %%
theirData = pd.read_csv('Marcy_Spreadsheet.csv')
print(theirData.head)
# Out:
# <bound method NDFrame.head of       Name  Age     Sex           Height Commute Time  Transportation  \
# 0    Itzel   21  Female              5'2      70 mins  R , A ,L Train
# 1    Angel   19    Male  5'11 with timbs  100 minutes  Bx27/6&N train
# 2    Kabbo   24    Male              5'9  150 minutes       Q42, J, N
# 3  Vincent   24    Male              5'7           60       A/D Train
#
#   Fav Color     Fav Fruit Andriod Or Iphone   Country Of Origin         Race  \
# 0    purple  pomegranates           Andriod               U.S.A       Latino
# 1    Purple    Watermelon            Iphone  Dominican Republic  Afro-Latino
# 2     Black        Apples            iPhone          Bangladesh  South Asian
# 3     Beige        banana            iphone   Domincan Republic  Afro-Latino
#
#    Birthday  # of Siblings   Favorite Pizza Fav Genre  \
# 0   9/18/03              3  Buffalo chicken     metal
# 1  10/19/05              2    Chicken Ranch       Pop
# ...

# %%
ourKeys = ourData.keys()

# %%
theirKeys = theirData.keys()

# %%
data1 = ourKeys.tolist()
data2 = theirKeys.tolist()
print(data1)
print(data2)
# Out:
# ['Name', 'Age (Years)', 'Gender/Sex', 'Height (Inch)', 'Commute Time (Mins)', 'Favorite Color', 'Favorite Fruit', 'Android or iphone', 'Birthday (MM/DD)', 'Race', '# of Siblings', 'Favorite Pizza', 'Fav Genre', 'Languages Spoken', 'Borough', 'Dream Job', 'Dream Company']
# ['Name', 'Age', 'Sex', 'Height', 'Commute Time', 'Transportation', 'Fav Color', 'Fav Fruit', 'Andriod Or Iphone', 'Country Of Origin', 'Race', 'Birthday', '# of Siblings', 'Favorite Pizza', 'Fav Genre', 'Languages Spoken', 'Borough', 'Dream Job', 'Dream Company']

# %%
print(len(ourKeys))
print(len(theirKeys))
# Out:
# 17
# 19

# %%
lower1 = []
for element in data1:
    low = element.lower()
    lower1.append(low)

# %%
print(lower1)
# Out:
# ['name', 'age (years)', 'gender/sex', 'height (inch)', 'commute time (mins)', 'favorite color', 'favorite fruit', 'android or iphone', 'birthday (mm/dd)', 'race', '# of siblings', 'favorite pizza', 'fav genre', 'languages spoken', 'borough', 'dream job', 'dream company']

# %%
lower2 = []
for element in data2:
    low = element.lower()
    lower2.append(low)

# %%
print(lower2)
# Out:
# ['name', 'age', 'sex', 'height', 'commute time', 'transportation', 'fav color', 'fav fruit', 'andriod or iphone', 'country of origin', 'race', 'birthday', '# of siblings', 'favorite pizza', 'fav genre', 'languages spoken', 'borough', 'dream job', 'dream company']

# %%
ourData.head()
# Out:
#         Name  Age (Years) Gender/Sex  Height (Inch)  Commute Time (Mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   Favorite Color Favorite Fruit Android or iphone Birthday (MM/DD)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              Race  # of Siblings   Favorite Pizza Fav Genre  Languages Spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
ourData.columns = lower1

# %%
ourData.head()
# Out:
#         name  age (years) gender/sex  height (inch)  commute time (mins)  \
# 0  Ibrahima            22       Male             68                  120
# 1    Rolando           22       Male             69                   60
# 2     Thomas           22       Male             69                   80
# 3      Kevin           22       Male             68                   80
#
#   favorite color favorite fruit android or iphone birthday (mm/dd)  \
# 0          Black         Mango            Android            08/07
# 1          Green          Mango            Iphone            12/25
# 2           Blue          Mango           Android            10/31
# 3           Blue          Mango            IPHONE            06/11
#
#              race  # of siblings   favorite pizza fav genre  languages spoken  \
# 0        Africain              4  Buffalo chicken     Black               4.0
# 1  White/Hispanic              2        Margarita  Shoegaze               2.5
# ...

# %%
theirData.columns = lower2

# %%
theirData.head()
# Out:
#       name  age     sex           height commute time  transportation  \
# 0    Itzel   21  Female              5'2      70 mins  R , A ,L Train
# 1    Angel   19    Male  5'11 with timbs  100 minutes  Bx27/6&N train
# 2    Kabbo   24    Male              5'9  150 minutes       Q42, J, N
# 3  Vincent   24    Male              5'7           60       A/D Train
#
#   fav color     fav fruit andriod or iphone   country of origin         race  \
# 0    purple  pomegranates           Andriod               U.S.A       Latino
# 1    Purple    Watermelon            Iphone  Dominican Republic  Afro-Latino
# 2     Black        Apples            iPhone          Bangladesh  South Asian
# 3     Beige        banana            iphone   Domincan Republic  Afro-Latino
#
#    birthday  # of siblings   favorite pizza fav genre  \
# 0   9/18/03              3  Buffalo chicken     metal
# 1  10/19/05              2    Chicken Ranch       Pop
# 2   7/16/00              1              Pep   Hip-Hop
# ...
