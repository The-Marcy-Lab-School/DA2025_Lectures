# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/Marcy_Student/Desktop/restaurant_inspection.csv')

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('-', '_')

# %%
df['INSPECTION_DATE'] = pd.to_datetime(df['INSPECTION_DATE'], errors='coerce')

# %%
df.shape
# Out:
# (41100, 27)

# %%
df = df[(df['INSPECTION_DATE'] >= '2025-06-01') & (df['INSPECTION_DATE'] < '2025-11-04')]

# %%
df.to_csv('/Users/Marcy_Student/Desktop/Marcy_Lab/DA2025_Lectures/Mod6/data/restaurant_inspection_cleaned.csv', index=False)
