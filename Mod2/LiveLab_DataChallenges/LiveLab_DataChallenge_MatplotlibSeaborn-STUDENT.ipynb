# %% [markdown]
# ### Live Lab AND Data Challenge:  Matplotlib & Seaborn

# %% [markdown]
# You are given sample data for visitors that visit a webiste per day and signup for an account.  Your job is to create 8 visuals (4 in matplotlib and 4 in seaborn) to visualize the following:
#
# -- Line chart of Visitors over Time
#
# -- Histogram of Signups
#
# -- Scatter plot of Visitors vs Signups
#
# -- Bar chart of Average Signups per Visitor Range
#
# Replace the word `None` with your code

# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create the dataset
data = {
    'Day': list(range(1, 11)),
    'Visitors': [100, 120, 110, 130, 150, 140, 160, 170, 180, 175],
    'Signups': [5, 8, 6, 10, 12, 11, 13, 15, 16, 14]
}

df = pd.DataFrame(data)

# Optional: Set Seaborn style
sns.set(style="whitegrid")

# Create a figure with 4 rows and 2 columns to make 8 visuals
fig, axs = plt.subplots(4, 2, figsize=(12, 16))
fig.suptitle("Matplotlib vs Seaborn Visualizations", fontsize=16)

# Task 1: Line chart of Visitors over Time -- Matplotlib
axs[0, 0].plot(df['Day'], df['Visitors'], marker='o', color='blue')
axs[0, 0].set_title("Matplotlib: Visitors Over Time")
axs[0, 0].set_xlabel("Day")
axs[0, 0].set_ylabel("Visitors")

# Task 1: Line chart of Visitors over Time -- Seaborn
sns.lineplot(x='Day', y='Visitors', data=df, ax=axs[0, 1])
axs[0, 1].set_title('Seaborn: Visitors Over Time')
axs[0, 1].set_xlabel("Day")
axs[0, 1].set_ylabel("Visitors")

# Task 2: Histogram of Signups -- MatplotLib
axs[1, 0].hist(df['Signups'], bins=5, color='orange', edgecolor='black')
axs[1, 0].set_title("Matplotlib: Signup Distribution")
axs[1, 0].set_xlabel("Signups")
axs[1, 0].set_ylabel("Frequency")

# Task 2: Histogram of Signups -- Seaborn

sns.histplot(data=df,x='Signups', bins=5, kde=False, color='orange', ax=axs[1, 1])
axs[1, 1].set_title("Seaborn: Signup Distribution")
axs[1, 1].set_xlabel('Signups')
axs[1, 1].set_ylabel("Frequency")

# Task 3: Scatter plot of Visitors vs Signups -- Matplotlib
axs[2, 0].scatter(df['Visitors'], df['Signups'], color='green')
axs[2, 0].set_title("Matplotlib: Visitors vs Signups")
axs[2, 0].set_xlabel("Visitors")
axs[2, 0].set_ylabel("Signups")


# Task 3: Scatter plot of Visitors vs Signups -- Seaborn
sns.scatterplot(x='Visitors', y='Signups', data=df, ax=axs[2,1], color='green')
axs[2, 1].set_title("Seaborn: Visitors vs Signups")
axs[2, 1].set_xlabel("Visitors")
axs[2, 1].set_ylabel('Signups')

# Creating a variable for a bar chart -- what does this code do?
df['Visitor_Bin'] = pd.cut(df['Visitors'], bins=3)
signup_avg = df.groupby('Visitor_Bin')['Signups'].mean().reset_index()


# Task 4: Bar chart of average Signups per Visitor Bin - Matplotlib

axs[3, 0].bar(signup_avg['Visitor_Bin'].astype(str), signup_avg['Signups'], color='purple')
axs[3, 0].set_title("Matplotlib: Avg Signups by Visitor Range")
axs[3, 0].set_xlabel('Visitor Range')
axs[3, 0].set_ylabel('Avg Signups')


# Task 4: Bar chart of average Signups per Visitor Bin - Seaborn
sns.barplot(x='Visitor_Bin', y='Signups', data=signup_avg, ax=axs[3, 1], palette='muted')
axs[3, 1].set_title('Seaborn: Avg Signups by Visitor Range')
axs[3, 1].set_xlabel("Visitor Range")
axs[3, 1].set_ylabel("Average Signups")
axs[3, 1].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /var/folders/78/8f22v_ln4kvg9b_7fr3_2nfh0000gn/T/ipykernel_74263/2967453144.py:62: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   signup_avg = df.groupby('Visitor_Bin')['Signups'].mean().reset_index()
# /var/folders/78/8f22v_ln4kvg9b_7fr3_2nfh0000gn/T/ipykernel_74263/2967453144.py:74: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Visitor_Bin', y='Signups', data=signup_avg, ax=axs[3, 1], palette='muted')

# %% [markdown]
# Task 1:
# - App visitors are increasing over time.
# Task 2:
# - It seems to be skewed to the right as the frequency is higher.
# Task 3:
# - Yes, in general. There is an outlier that is visible in the graph but that can be due to other factors.
# Task 4:
# - As the avg sign ups increases, the visitor range also increases.
#
# Bonus:
# - Excel and Tableu is good for quick EDA but if I want to do a thorough analysis, I would do it in Python as I have more granular control over my data. Plus, I can do more complex analysis in less steps in Python.

# %%
import plotly.express as px #pip install this if you don't have the package 
import pandas as pd

# Sample data (similar to gapminder for illustration)
data = {
    'year': [2000, 2005, 2010, 2015, 2020, 2000, 2005, 2010, 2015, 2020],
    'borough': ['Manhattan', 'Manhattan', 'Manhattan', 'Manhattan', 'Manhattan', 'Brooklyn', 'Brooklyn', 'Brooklyn', 'Brooklyn', 'Brooklyn'],
    'population': [1537000, 1594000, 1636000, 1665000, 1695000, 2465000, 2504000, 2556000, 2636000, 2736000],
    'gdpPercap': [40000, 45000, 50000, 55000, 60000, 20000, 22000, 24000, 26000, 28000] # dummy gdp
}
df_borough = pd.DataFrame(data)

fig = px.line(df_borough, x='year', y='population', color='borough',
              title='Population Trends by Borough',
              hover_name='borough',
              labels={'population': 'Population', 'year': 'Year'})
fig.show()

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")
px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent", hover_name="country", log_x=True)

# %%
import pandas as pd
df_line = pd.DataFrame({
    'Month':['Jan', 'Feb', 'Mar', 'Apr', 'Jun','May'],
    'Visitors':[1200,1500,1600,1400,1700,1800]
})

fig = px.line(df_line, x='Month', y='Visitors', title="Monthly App Visitors")
fig.show()

# %%
import plotly.express as px
import pandas as pd

df_bar = pd.DataFrame({
    'Category':['Shoes', 'Accessories', 'Outwear', 'Tops', 'Bottoms'],
    'Sales':[24000,14000,18000,22000,20000]
})

fig = px.bar(df_bar, x='Category', y='Sales', title="Sales by Product Category", text='Sales')
fig.update_traces()
fig.show()
