# %%
import sys
print(sys.executable)
# Out:
# /opt/miniconda3/envs/data-analysis-env/bin/python

# %%
# !pip install dash
import dash
print(dash.__version__)
# Out:
# Collecting dash
#   Using cached dash-3.1.1-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting Werkzeug<3.2 (from dash)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (6.0.1)
# Requirement already satisfied: importlib-metadata in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Using cached retrying-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: nest-asyncio in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from dash) (79.0.1)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (1.36.0)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages (from requests->dash) (2025.1.31)
# Using cached dash-3.1.1-py3-none-any.whl (7.9 MB)
# Using cached flask-3.1.1-py3-none-any.whl (103 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached retrying-1.4.0-py3-none-any.whl (11 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: Werkzeug, retrying, itsdangerous, click, blinker, Flask, dash
# Successfully installed Flask-3.1.1 Werkzeug-3.1.3 blinker-1.9.0 click-8.1.8 dash-3.1.1 itsdangerous-2.2.0 retrying-1.4.0
# 3.1.1

# %%
import dash
from dash import html, dcc
import plotly.express as px
import pandas as pd

app = dash.Dash(__name__)

# Sample data
data_sample = {
    'Category': ['A', 'B', 'C', 'D'],
    'Value': [10, 20, 15, 25]
}
df_sample = pd.DataFrame(data_sample)

fig = px.bar(df_sample, x='Category', y='Value', title='Simple Bar Chart')

# Layout
app.layout = html.Div([
    html.H1('My First Dash App'),
    dcc.Graph(figure=fig)
])

if __name__ == '__main__':
    # This will run the app locally, typically at http://127.0.0.1:8050/
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:54112/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.
#
# ---------------------------------------------------------------------------
# MethodNotAllowed                          Traceback (most recent call last)
# MethodNotAllowed: 405 Method Not Allowed: The method is not allowed for the requested URL.

# %%
import dash
from dash import html, dcc

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Hello Dash!"),
    dcc.Graph(id='example-chart')
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ObsoleteAttributeException                Traceback (most recent call last)
# Cell In[7], line 12
#       6 app.layout = html.Div([
#       7     html.H1("Hello Dash!"),
#       8     dcc.Graph(id='example-chart')
#       9 ])
#      11 if __name__ == '__main__':
# ---> 12     app.run_server(debug=True)
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/dash/_obsolete.py:22, in ObsoleteChecker.__getattr__(self, name)
#      20 if name in self._obsolete_attributes:
#      21     err = self._obsolete_attributes[name]
# ---> 22     raise err.exc(err.message)
#      23 return getattr(self.__dict__, name)
#
# ObsoleteAttributeException: app.run_server has been replaced by app.run
